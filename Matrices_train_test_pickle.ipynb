# %% [markdown]
# Anime Recomendation Datasbase 2020
#
#
# ***Descripión***:
#
# En esta notebook se encuentra la división del dataset en conjuntos de entrenamiento y prueba, su posterior factorización, y finalmente la serialización de las matrices resultantes. Estos insumos se utilizaron para ajustar y evaluar el rendimiento del modelo de recomendación.

# %%
import pandas as pd
import numpy as np

# %%
pip install scikit-learn lightfm scikit-optimize

# %%
from lightfm import LightFM

# %%
from sklearn.model_selection import train_test_split

# %%
from lightfm.data import Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/TP FINAL ICARO/Copia de rating_complete_filtrado.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0  user_id  anime_id  rating
# 0         189        3     25835       8
# 1         190        3     28171       8
# 2         191        3     32282       8
# 3         192        3     35788       9
# 4         193        3      9253       9

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
df.shape
# Out:
# (46586264, 3)

# %%
anime.shape
# Out:
# (17562, 35)

# %%
df.user_id.nunique()
# Out:
# 125566

# %%
df.anime_id.nunique()
# Out:
# 16868

# %%
train, test = train_test_split(df, test_size=0.3, random_state=0)

# %%
test[~test.user_id.isin(train.user_id.unique())].user_id.nunique()
# Out:
# 0

# %%
train.sample(5)
# Out:
#           user_id  anime_id  rating
# 40368257   306058      1454       8
# 13642759   103696      2167       1
# 39804565   301821     28025       7
# 17316543   131742      2604       8
# 9085150     68706      3702      10

# %%
test_data_filtered = test[test['anime_id'].isin(train['anime_id']) & test['user_id'].isin(train['user_id'])]

# %%
dataset = Dataset()
dataset.fit(train['user_id'], train['anime_id'])

# %%
# %%time
(interactions_train, _) = dataset.build_interactions([(x['user_id'], x['anime_id'], x['rating']) for index, x in train.iterrows()])
# Out:
# CPU times: user 30min 31s, sys: 14.4 s, total: 30min 45s
# Wall time: 31min 8s

# %%
# %%time
(interactions_test, _) = dataset.build_interactions([(x['user_id'], x['anime_id'], x['rating']) for index, x in test_data_filtered.iterrows()])
# Out:
# CPU times: user 13min 9s, sys: 2.51 s, total: 13min 12s
# Wall time: 13min 21s

# %%
import pickle

# %%
with open('matriz_interacciones.pickle', 'wb') as f:
    pickle.dump(interactions_train, f)

# %%
with open('interacciones_test.pickle', 'wb') as f:
    pickle.dump(interactions_test, f)
